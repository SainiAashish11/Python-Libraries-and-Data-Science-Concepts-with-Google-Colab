# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Titanic Dataset ( train.csv )
df = pd.read_csv('/content/drive/MyDrive/DSMP Datasets colab/EDA  session datasets/train.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Why do EDA
# * ### Model Building - to build model and predict
# * ### Analysis and Reporting - Analyse the information from data and report
# * ### Validate Assumptions - to ensure that any assumption made on data is right or wrong
# * ### Handling missing values - to handle missing values on the basis of EDA actions
# * ### Feature engineering - which columns are useful or need to make new columns
# * ### Detecting outliers - data out of the box

# %% [markdown]
# ## `Remember : It is an iterative process to perform EDA`

# %% [markdown]
# ## Step-1: Assigning Column type
# * ### Numerical - Age , Fare , PassengerId
# * ### Categorical - Survived, Pclass , Sex , SibSp , Parch , Embarked
# * ### Mixed - Name , Ticket , Cabin

# %% [markdown]
# ## Step-2: Univariate Analysis
# ### Univariate Analysis focuses on analyzing each feature(column) in dataset independently
#
# * ### Distribution Analysis : The distribution of each feature(column) is examined to identify its shape, central tendency(mean , median , mode) and dispersion.
# * ### Identifying Potential Issues : Univariate Analysis helps in identifying potential problems with the data such as outliers, skewness and missing values.

# %% [markdown]
# ## ***Shape*** : The shape of a data distribution refers to its overall pattern or form as it is represented on a graph.
#
# ### Some common shapes of data distrubution include:
# * ### Normal Distribtution : A symmetrical and bell-shaped distribution where mean, median and mode are equal and the majority of the data falls in the middle of the distributiom with gradually decreasing frequecies towards the tails.
#
# * ### Skewed Distribution : A distribution that is not symmetrical, with one tail being longer that the other. It can be either `positively skewed ( right skewed / right side tail )` or `negatively skewed ( left skewed / left side tail )`.
#
# * ### Bimodal Distribution : A distribution with two peaks or modes.
#
# * ### Uniform Distribution : A distribution where all values have an equal chance of occurring.
#
# ### ✅ The shape of the data distribution is important in identifying the prescence of outliers, skewness and the type of statistical tests and models that can be used for further analysis.
#
# ## ***Dispersion*** : It is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a dataset are spread out from the `central tendency( mean , median , mode )` of the data
#
# ### There are several measures of dispersion :
# * ### Range : The difference between largest and smallest values in a dataset
# * ### Variance : The average of the squared deviations((X-μ)^2) of each values from the 'mean' of hte dataset
# * ### Standard Deviation : The square root the 'variance'. It provides a measure of the spread of the data that is in the same units as the original data.
# * ### Interquartile range : The range between the first quartile( 25the percentile ) and the third quartile ( 75th percentile ) of the data.
#
# ### ✅ Dispersion helps to describe the spread of the data, which can help to identify the prescence of outliers and skewness in the data.

# %% [markdown]
# # ⏩ Steps of doing Univariate Analysis on Numerical columns
# * ### **Descriptive statistics** : Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# * ### **Visualizations** : Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness and outliers.
#
# * ### **Identifying Outliers** : Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# * ### **Skewness check** : Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# * ### **Conclusion** : Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# # ✅ ***Univariate Analysis starts on Numerical columns***

# %% [markdown]
# ## 'Age' column
#
# ### **Conclusions**
# * ### Age is almost normally distributed
# * ### ~ 20% values are missing
# * ### There are some outliers present ( but normal as per the data relevancy )

# %%
# 1-decriptive analysis
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# 2-Visualization
df['Age'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].plot(kind = 'hist' , bins = 10)

# different bin sizes provide little idea that some 'Age' are not present in the data
df['Age'].plot(kind = 'hist' , bins = 20)
df['Age'].plot(kind = 'hist' , bins = 30)
df['Age'].plot(kind = 'hist' , bins = 40 , color = 'yellow')     # in 'yellow' graph , between age=60 and 70, some 'Age' are not present but that's normal
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 3-Identifying outliers
df['Age'].plot(kind = 'box')

# graph says that above 'Age' 60 there are some outliers present
df[df['Age'] > 60]
# Note : these passengers with Age > 60 are normal with respect to data as no such data is present to which you can say that this 'Age' is not possible or irrelevant wrt other passengers
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
# missing values detection
print(df['Age'].isnull().sum())   # '177' out of '891' passengers, the 'Age' data is missing which is not a good thing at all

# total passengers
df.shape[0]    # fetching out only 'total rows' which is equal to 'total passengers'

# percentage of data is missing
print(df['Age'].isnull().sum() / df.shape[0])     # ~ 19.8% data is missing
# Out:
# 177
# 0.19865319865319866

# %%
# 4-skewness check
print(df['Age'].skew())

# Note : more '+ve number' means '+ve skewness' and more '-ve number' means '-ve skewness'
# Out:
# 0.38910778230082704

# %% [markdown]
# ## 'Fare' column -> ticket price
#
# ### **Conclusions**
# * ### Data is highly skewed ( +vely skewed )
# * ### Fare prices are written in `group manner( total Fare )` for a family travelling on same ticket number
# * ### We need to create a new column as 'Individual Fare' for different passengers travelling on same ticket number

# %%
# 1-Descriptive analysis
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# 2-Visualization
df['Fare'].plot(kind = 'kde')

# Note : skewness is present
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].plot(kind = 'box')

# so many outliers are present
# Out:
# <Axes: >

# %%
# Identifying outliers
df[df['Fare'] > 250]

# Note : Some passengers have same ticket and Fare data values means if any family is travelling then those family members are travelling on same 'ticket number' and 'total fare' is written in front of every family member's 'id'
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# # ⏩ Steps of doing Univariate Analysis on Categorical columns
#
# * ### **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# * ### **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# * ### **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# * ### **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# # ✅ ***Univariate Analysis starts on Categorical columns***

# %% [markdown]
# ## 'Survived' column -> passenger survived or not
#
# ### **Conclusions**
#
# * ### more than 50% passengers died
# * ### no missing values present

# %%
# 1-Descriptive Analysis ( value_counts() )
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# 2-Visualization
df['Survived'].value_counts().plot(kind = 'bar')    # 'bar' plot on 'frequency distribution( survived = 1 and not-survived = 0 )
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')

# Note : more than 50% passengers died
# Out:
# <Axes: ylabel='count'>

# %%
# 3-missing values
print(df['Survived'].isnull().sum())

# Note : no missing values
# Out:
# 0

# %% [markdown]
# ## 'Pclass' column -> class of the ship : 1(costly) > 2 > 3(cheapest)
#
# ### **Conclusions**
# * ### Surprisingly more people travelled in 'Pclass = 2' than 'Pclass = 1' although prices for 'Pclass = 1' was costly as compare to 'Pclass = 2'
# * ### no missing values

# %%
# 1-Descriptive Analysis
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# 2-Visualization
df['Pclass'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 3-Missing values
print(df['Pclass'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## 'Sex' column
#
# ### **Conclusions**
# * ### Males are more than Females
# * ### No missing values

# %%
# 1-Descriptive Analysis
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# 2-Visualization
df['Sex'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 3-Missing values
print(df['Sex'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## 'SibSp' column -> siblings or spouse/husband travellers with passenger
#
# ### **Conclusions**
# * ### mostly passengers are travelling alone ( without siblings or spouse/husband )
# * ### No missing values

# %%
# 1-Descriptive Analysis
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
# 2-Visualization
df['SibSp'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 3-Missing values
print(df['SibSp'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## 'Parch' column -> parent or children
#
# ### **Conclusions**
# * ### 'Parch' and 'SibSp' columns can merged to form a new column as 'Family_size'
# * ### Create a new column called 'is_alone' -> means passenger was travelling alone or not
# * ### No missing values

# %%
# 1-Descriptive Analysis
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
# 2-Visualization
df['Parch'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
df['Parch'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 3-Missing values
print(df['Parch'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## 'Embarked' column -> from which station you boarded titanic
#
# ### **Conclusions**
# * ### mostly people boarded from 'S' station which was the first station from where ship started
# * ### 2 missing values

# %%
# 1-Descriptive Analysis
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# 2-Visualization
df['Embarked'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 3-Missing values
print(df['Embarked'].isnull().sum())
# Out:
# 2

# %% [markdown]
# ## ✅ Mixed Columns
# * ### we need to perform 'featrue engineering' before working with `mixed` columns so that we can fetch better insights.

# %% [markdown]
# # ⏩ Steps of doing Bivariate Analysis
# * ### Select 2 columns
# * ### Understand type of relationship
# ## 1. **Numerical - Numerical**
#
# * ### a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots
#
# * ### b. Check correlation coefficent to check linear relationship
#
# ## 2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
#
# * ### a. You can plot graphs like barplot, boxplot, kdeplot, violinplot and even scatterplots
#
# ## 3. **Categorical - Categorical**
#
# * ### a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.
#
# * ### b. You can plots like heatmap, stacked barplots, treemaps

# %% [markdown]
# # Categorical-Categorical columns

# %% [markdown]
# ## 'Survived' and 'Pclass' columns
#
# ### **Conclusion**
# * ### 'Pclass = 3' passengers died more as compare to other class ( 75.7% )

# %%
# 1-descriptive analysis

# Take the main column which is relevant to the model prediction
# Model prediction is to predict whether the person will survive or die in 'Titanic'

# 'Survived' and 'Pclass' columns -> categorical-categorical analysis
# make a contingency table with pd.crosstab() function

display(pd.crosstab(df['Survived'] , df['Pclass']))

# Note : This data tells that how many passengers survived or died in any 'Pclass'


# percentage using 'normalize' parameter
# normalize = 'columns' or 'index'
pd.crosstab(df['Survived'] , df['Pclass'] , normalize = 'columns')*100
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
# 2- Visualization
sns.heatmap(pd.crosstab(df['Survived'] , df['Pclass'] , normalize = 'columns')*100)

# Lighter shade telling more people died , dark shade means more survival
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ## 'Survived' and 'Sex' columns
#
# ### **Conclusion**
# * ### Female passengers survived more compared to Male

# %%
# 1- descriptive analysis
pd.crosstab(df['Survived'] , df['Sex'] , normalize = 'columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
# Visualization - No need to visualize coz data is telling all

# %% [markdown]
# ## 'Survived' and 'Embarked' columns
#
# ### **Conclusion**
# * ### Passengers boarded from 'Q' and 'S' stations died more compared to 'C'

# %%
# 1- descriptive analysis
pd.crosstab(df['Survived'] , df['Embarked'] , normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
# Visualization - No need for now

# %% [markdown]
# # Categorical-Numerical columns

# %% [markdown]
# ## 'Survived' and 'Age'
#
# ### **Conclusion**
# * ### Age factor matters in survival or dying
# * ### Age = 0-10 ( kids ) survival is more than 10-40 range and in 10-40 range, passengers survival is good as well coz mostly they are sitting in 'Pclass = 1'

# %%
# Plot numerical data distiburtion over all categories of categorical column using 'kde' plot
df[df['Survived'] == 1]['Age'].plot(kind = 'kde' , label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind = 'kde' , label = 'Not Survived')

plt.legend()
plt.show()

# %% [markdown]
# ## **Feature engineering**
#
# ### What to do :
# * ### 1). To study 'Fare' column in which total fare is present right now for any passenger whether any other person travelled with them or not
#
# * ### 2). To study 'SibSp' and 'Parch' columns we need to merge these columns into new column called 'Family_size'
# * ### 3). To study 'Name' column we need to make a new 'Surname' and 'Title' columns
# * ### 4). To study 'Cabin' column we need to fetch categorise passengers with their 'Deck'

# %% [markdown]
# ## 1). Fare Column
# * ### 'SibSp' and 'Parch' columns have those people who travelled on same 'ticket' number but different 'PassengerId'
# * ### We need to calculate the individual fare of a person by dividing the 'Fare' value with total passengers travelled on the same 'Ticket' number
# * ### Before any step, we need to join the train and test tables to see all the entries

# %%
# Concatenating the 'train' and 'test' tables
df1 = pd.read_csv('/content/drive/MyDrive/DSMP Datasets colab/EDA  session datasets/train.csv')
df2 = pd.read_csv('/content/drive/MyDrive/DSMP Datasets colab/EDA  session datasets/test.csv')

df = pd.concat([df1 , df2])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Calculating individual_fare and adding column to 'df' dataframe
df['Individual_fare'] = df['Fare'] / (df['SibSp'] + df['Parch'] + 1)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 2). 'Family_type' column creation using 'Family_size' column by merging 'SibSp' and 'Parch' columns

# %%
# 'Family_size' as new column
df['Family_size'] = df['SibSp'] + df['Parch'] + 1

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# creatiing 'Family_type' column to judge whether person is alone, family is small or family is large

# creating function to judge and assign family type
def transform_family_size(num):
  if num == 1:
    return 'alone'

  elif num > 1 and num < 5:
    return 'small'

  else:
    return 'large'

# calling function on 'Family_size' column using 'apply()' function
df['Family_type'] = df['Family_size'].apply(transform_family_size)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Bivariate analysis on 'Survived' and 'Family_type' columns
#
# ### **Conclusion**
# * ### Being in a 'small family', your chanches of survival are higher then being 'alone' and in a 'large family'

# %%
pd.crosstab(df['Survived'] , df['Family_type'] , normalize = 'columns') * 100   # 'normalize' parametes is normalizing the numerical data on given value i.e. columns/index
# Out:
# Family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %% [markdown]
# ## 3). 'Surname' and 'Title' column creation

# %%
# creating 'Surname' column
df['Surname'] = df['Name'].str.split(',').str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
# creating 'Title' column
df['Title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Major.         2
# Mlle.          2
# Ms.            2
# Mme.           1
# Don.           1
# Sir.           1
# Lady.          1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: count, dtype: int64

# %%
# replace 'special Titles' with 'Other'
title_mapping = {
    'Rev.': 'Other',
    'Dr.': 'Other',
    'Col.': 'Other',
    'Major.': 'Other',
    'Mlle.': 'Other',
    'Ms.': 'Miss.',
    'Mme.': 'Mrs.',
    'Don.': 'Other',
    'Sir.': 'Other',
    'Lady.': 'Mrs.',
    'Capt.': 'Other',
    'the': 'Other',
    'Jonkheer.': 'Other',
    'Dona.': 'Mrs.'
}

# Apply the mapping to the 'Title' column
df['Title'] = df['Title'].replace(title_mapping)

df['Title'].value_counts()
# Out:
# Title
# Mr.        757
# Miss.      260
# Mrs.       197
# Master.     61
# Other       34
# Name: count, dtype: int64

# %% [markdown]
# ### Bivariate Analysis on 'Survived' and 'Title' columns
# ### **Conclusion**
# * ### 'Miss' and 'Mrs' hone se aapke bachne ke chances are much higher

# %%
# analysis on 'Title' and 'Survived' columns
pd.crosstab(df['Survived'] , df['Title'] , normalize = 'columns') * 100
# Out:
# Title     Master.     Miss.        Mr.  Mrs.      Other
# Survived
# 0.0          42.5  30.21978  84.332689  20.8  55.555556
# 1.0          57.5  69.78022  15.667311  79.2  44.444444

# %% [markdown]
# ## 'Deck' column
# ### **Conclusion**
# * ### passengers in B,C,D,E and F decks have higher chances of Survival

# %%
# fill missing values first
df['Cabin'] = df['Cabin'].fillna('M')

# Store Cabin type in new 'Deck' column
df['Deck'] = df['Cabin'].str.get(0)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_fare  \
# 0      0         A/5 21171   7.2500     M        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250     M        S          7.92500
# ...

# %%
# different Decks and how many passengers present in them
df['Deck'].value_counts()
# Out:
# Deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
# Analysis on 'Survived' and 'Deck' columns
pd.crosstab( df['Deck'] , df['Survived'] , normalize = 'index') * 100
# Out:
# Survived         0.0        1.0
# Deck
# A          53.333333  46.666667
# B          25.531915  74.468085
# C          40.677966  59.322034
# D          24.242424  75.757576
# E          25.000000  75.000000
# F          38.461538  61.538462
# G          50.000000  50.000000
# M          70.014556  29.985444
# T         100.000000   0.000000

# %%
# Visulaization
(pd.crosstab( df['Deck'] , df['Survived'] , normalize = 'index')* 100).plot(kind = 'bar' , stacked = True)
# Out:
# <Axes: xlabel='Deck'>
