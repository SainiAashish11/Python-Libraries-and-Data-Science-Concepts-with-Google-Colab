# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
#!/bin/bash
# !kaggle datasets download andrewmvd/face-mask-detection
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/face-mask-detection
# License(s): CC0-1.0
# ...
#  98% 388M/398M [00:01<00:00, 197MB/s]
# 100% 398M/398M [00:01<00:00, 227MB/s]

# %% [markdown]
# To change the permissions of the .json file to user only

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# Run zipfile module code to extract the content of the .zip dataset

# %%
import zipfile
zip_ref = zipfile.ZipFile('face-mask-detection.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
