# %% [markdown]
# # Why Seaborn ?
# - Provides a layer of abstraction hence simpler to use
# - Better asethetics
# - more graphs included
# - Statistically strong for ML model evaluation and EDA

# %% [markdown]
# # Seaborn Roadmap
# ### Types of functions :
# - Figure Level : Figure object to make figure of plotting
# - Axis Level   : Axis object for axes-plotting
#
# ### Main Classification
# - Relational Plot
# - Distribution Plot
# - Categorical Plot
# - Regression Plot
# - Matrix plot
# - Multiplots

# %% [markdown]
# ## 1.Relational Plot
# - Scatter plot
# - Line plot
#
#
# ### ⚡To see the statistical relation between 2 or more variables
# ### ⚡Bivariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ### 1.1-Scatter Plot

# %%
# loading Dataset
tips = sns.load_dataset('tips')    # 'tips' Dataset loading

# using axes-level function i.e. 'scatterplot()'
sns.scatterplot(data = tips , x = 'total_bill' , y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# using relplot() -> figure level function
sns.relplot(data = tips , x = 'total_bill' , y = 'tip' , kind = 'scatter')

# Note : using 'Figure-level' functions is way more better than using 'axes-level' function because you can have access to the whole figure not only axes of the graphs

# %%
# Some Parameters :
# hue   -> for color mapping of different categories of column data
# style -> for data-formatting having different characters based on 'column' data
# size  -> for size of the marker used on based of a integer-column

sns.relplot(data = tips , x = 'total_bill' , y = 'tip' , hue = 'sex' , style = 'time' , size = 'size')

# %% [markdown]
# ### 1.2-Line plot

# %%
# 'gap' dataset from 'plotly' library
gap = px.data.gapminder()
display(gap)

# plot 'India' ka year vs lifeExpectancy line plot
# step-1- filter India from 'country'
temp_df = gap[gap['country'] == 'India']

# step-2- Plot on 'year' and 'lifeExp' column
sns.lineplot(data = temp_df , x = 'year' , y = 'lifeExp')    # sns.lineplot() is axes-level function
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
# plot using relplot() -> figure-level function
sns.relplot(data = temp_df , x = 'year' , y = 'lifeExp' , kind = 'line')

# %%
# hue ( color grading )
df = gap[gap['country'].isin(['India' , 'China' , 'Pakistan'])]                          # selecting 3 countires

sns.relplot(data = df , x = 'year' , y = 'lifeExp' , kind = 'line' , hue = 'country')    # applying 'hue' parameter on 'country' column

# %%
# style ( like -> dashed , dotted , solid line)
df = gap[gap['country'].isin(['India' , 'Brazil' , 'China'])]

sns.relplot(data = df , x = 'year' , y = 'lifeExp' , kind = 'line' , hue = 'country' , style = 'continent')

# %%
# size ( thickness in line )
df = gap[gap['country'].isin(['India' , 'Brazil' , 'China'])]

sns.relplot(data = df , x = 'year' , y = 'lifeExp' , kind = 'line' , hue = 'country' , style = 'continent' , size = 'continent')

# %% [markdown]
# ### Facet Plot : Use to plot multiple plots on categorical column( like male and female )
# - works only with 'figure-level' function not 'axes-level' function

# %%
sns.relplot(data = tips , x = 'total_bill' , y = 'tip' , kind = 'scatter' , col = 'smoker' , row = 'sex')      # col = 'smoker' and row = 'sex' creating combinations of 2x2 = 4 graphs

# %%
# col_wrap = integer -> jyada categories hai agar columns mein toh tab ye kaam aata hai
# jitna 'integer' value hai utne plots '1-row' mein aayenge and fir rows mein distribute ho jayenge
# jitna 'integer' value hai utne ka jump bhi le lega to plot multiple graphs
sns.relplot(data = gap , x = 'lifeExp' , y = 'gdpPercap' , kind = 'scatter' , col = 'year' , col_wrap = 4)

# %% [markdown]
# ## 2. Distribution Plot : tells how the data is distributed
# - Used for Univariate Analysis
# - Used to find out the distribution
# - Range of the observation
# - Central tendency ( mean , median , mode )
# - Is the Data bimodal ? -> multiple peaks in the data
# - Are there outliers ?
#
# ## Plots under Distribution Plot
# - Histogram
# - kde plot
# - Rug plot

# %% [markdown]
# ### Figure level function
# - displot
#
# ### Axes level functions
# - histplot
# - kdeplot
# - rigplot

# %% [markdown]
# ### 2.1- Hist Plot : A histogram is a graphical representation that organizes a group of data points into user-specified ranges( **Bins** ). It is used to visualize the distribution of a single numerical variable, showing where the values are concentrated and how frequently they occur.

# %%
# plotting univariate histogram using 'tips' dataset
sns.histplot(data = tips , x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# using 'displot'
sns.displot(data = tips , x = 'total_bill' , kind = 'hist')

# %%
# 'bins' parameter
sns.displot(data = tips , x = 'total_bill' , kind = 'hist' , bins = 20)

# %%
# It is possible to plot 'histogram' on categorical data as well
# Discrete bins are automatically set for categorical variables

# Technically this is not 'histogram' but a 'CountPlot'
sns.displot(data = tips , x = 'day' , kind = 'hist')

# %%
# 'hue' parameter : color grading for different categories of data present in the column
sns.displot(data = tips , x = 'tip' , kind = 'hist' , hue = 'sex')

# %%
# 'element' parameter : to show only the lining of the histogram
sns.displot(data = tips , x = 'tip' , kind = 'hist' , hue = 'sex' , element = 'step')

# %%
# faceting ->  cols and rows : used only in figure level function
sns.displot(data = tips , x = 'tip' , kind = 'hist' , col = 'sex' , element = 'step')

# %% [markdown]
# ### 2.2- kde Plot ( Kernel Density Plot ) : Rather than using discrete bins like 'histogram' , a 'kde' plot smoothes the observation with a Gaussuian Kernel, producing a continuous density estimate

# %%
# sns.kdeplot -> axes level function
sns.kdeplot(data = tips , x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# sns.displot -> figure level function
sns.displot(data = tips , x = 'total_bill' , kind = 'kde' , hue = 'sex' , fill = True , height = 10 , aspect = 1.5)     # fill = True -> it fills the area of the plots

# Note :  height = 10 changes the height of the figure level graphs | aspect -> changes the width of the graph as 'width = height * aspect'

# %% [markdown]
# ### 2.3- Rug Plot
# - Plot marginal distributions by drawing ticks along x and y axes
# - This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way ( alag se dikh jana ).

# %%
# plotting 'rug' plot with 'kde' using axes-level functions
sns.kdeplot(data = tips , x = 'total_bill')
sns.rugplot(data = tips , x = 'total_bill')      # showing ticks on x-axis
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate analysis with Histogram -> rectangular grids showing concentration of data points (x , y)

# using axes-level function
sns.histplot(data = tips , x = 'total_bill' , y = 'tip')

# using figure-level function
sns.displot(data = tips , x = 'total_bill' , y = 'tip' , kind = 'hist')

# %%
# Bivariate 'kde' plot  -> line close to each other shows higher concentration of data points (x , y)

# using axes-level function
sns.kdeplot(data = tips , x = 'total_bill' , y = 'tip')

# using figure-level function
sns.displot(data = tips , x = 'total_bill' , y = 'tip' , kind = 'kde')

# %% [markdown]
# ## 3.Categorical Plots
# - Bar Plot
# - Count Plot
# - Box Plot
# - Violin Plot
# - Swam Plot

# %% [markdown]
# ## 4.Regression Plots : How one variable(like Hours study) affects another(like Exam Score).
#
# - Scatter Plot -> for actual data plot
# - Regression Line -> Draws the 'best fit' line through points to show trend

# %% [markdown]
# ## 5.Matrix plots : Plots on grid of data
# - Heat Map
# - Cluster Map

# %% [markdown]
# ### 5.1- Heatmap : Plots rectangular data as a color-encoded matrix

# %%
# plotting heatmap using 'gap' dataset

# convert 'gap' dataset into 'wide' format using 'pivot()' function
temp_df = gap.pivot(index = 'country' , columns = 'year' , values = 'lifeExp')

# plot using axes-level function i.e. 'sns.heatmap()'
plt.figure(figsize = (15 , 10))     # increasing size of graph of axes-level function(i.e. heatmap()) using this
sns.heatmap(temp_df)
# Note : dark -> light : life expectancy of country is increasing
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annot -> shows the value(integer / categorical ) of the data as well on data grids

# fetch European countries data only
temp_df = gap[gap['continent'] == 'Europe'].pivot(index = 'country' , columns = 'year' , values = 'lifeExp')

# plotting
plt.figure(figsize = (15 , 15))
sns.heatmap(temp_df , annot = True)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# linewidth -> provides the gap between the grid lines for better readability

# fetch European countries data only
temp_df = gap[gap['continent'] == 'Europe'].pivot(index = 'country' , columns = 'year' , values = 'lifeExp')

# plot now
plt.figure(figsize = (15 , 15))
sns.heatmap(temp_df , annot = True , linewidth = 0.5)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# cmap -> color of the graph

# fetch European countries data only
temp_df = gap[gap['continent'] == 'Europe'].pivot(index = 'country' , columns = 'year' , values = 'lifeExp')

# plot now
plt.figure(figsize = (15 , 15))
sns.heatmap(temp_df , annot = True , linewidth = 0.5 , cmap = 'viridis')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %% [markdown]
# ### 5.2- Cluster map : Similar data and non-similar data separation

# %%
# using 'iris' flower dataset
iris = px.data.iris()
iris

# plot cluster map
sns.clustermap(iris.iloc[: , [0 , 1 , 2 , 3]])   # iris.iloc[: , [0 , 1 , 2 ,3]] -> all rows and 0 ,1,2,3 columns fetching

# Note : in the graph, last two colored-maps on x-axis have good similarity than the others and on y-axis, data is showing similarity in rows

# %% [markdown]
# ## 6.MultiPlots
# - Joint Plot
# - Pair Plot
# - Facet Plot
